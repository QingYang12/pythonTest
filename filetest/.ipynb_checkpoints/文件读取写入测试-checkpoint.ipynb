# %% [markdown]
# ## 文件操作测试
# ### 1.文件读取

# %%
import os

print("开始")
fp=open("test1.txt","r")
temp=""
while temp != "NULL":
    temp=fp.readline()
    print(temp)
fp.close()
print("结束")
# Out:
# 开始
# 1111111
#
# 2222222
#
# 3333333,44444
#
# 5555,66666
#
# 77777
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/st/90r8rbhs3j16jvg9j1bm00k80000gn/T/ipykernel_1800/1380010846.py in <module>
#       5 temp=""
#       6 while temp != "NULL":
# ----> 7     temp=fp.readline()
#       8     print(temp)
#       9 fp.close()
#
# ~/opt/anaconda3/lib/python3.9/codecs.py in decode(self, input, final)
#     317         raise NotImplementedError
#     318
# --> 319     def decode(self, input, final=False):
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2.文件写入

# %%
import os

print("开始写入")
fp=open("test2.txt","w")
str="1231231231"
fp.write(str)
fp.close()
print("结束写入")
# Out:
# 开始写入
# 结束写入
